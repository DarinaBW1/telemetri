# %%
import hashlib
import string
import time
import itertools

# %%
def generate(alphabet, max_len):
    if max_len <= 1: return
    for c in alphabet:
        yield c
    for c in alphabet:
        for next in generate(alphabet, max_len-1):
            yield c + next

gen1 = generate('bts', 2)

for item1 in gen1:
    print(item1)
# Out:
# b
# t
# s

# %%
def generate(alphabet, max_len):
    if max_len <= 1: return
    for c in alphabet:
        yield c
    for c in alphabet:
        for next in generate(alphabet, max_len-1):
            yield c + next

gen2 = generate('BTS', 2)

for item2 in gen2:
    print(item2)
# Out:
# B
# T
# S

# %%
def generate(alphabet, max_len):
    if max_len <= 1: return
    for c in alphabet:
        yield c
    for c in alphabet:
        for next in generate(alphabet, max_len-1):
            yield c + next

gen3 = generate('123', 2)

for item3 in gen3:
    print(item3)
# Out:
# 1
# 2
# 3

# %%
#password='bts' 
res= hashlib.md5(item1.encode())
print(res.hexdigest())

#password='BTS' 
res= hashlib.md5(item2.encode())
print(res.hexdigest())

#password='123' 
res= hashlib.md5(item3.encode())
print(res.hexdigest())
# Out:
# 03c7c0ace395d80182db07ae2c30f034
# 5dbc98dcc983a70728bd082d1a47546e
# eccbc87e4b5ce2fe28308fd9f2a7baf3

# %%
password='bts' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='BTS' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='123' 
res= hashlib.md5(password.encode())
print(res.hexdigest())
# Out:
# c3ea886e7d47f5c49a7d092fadf0c03b
# e66b8a0acab164bdbf805b19348be653
# 202cb962ac59075b964b07152d234b70

# %%
password='b' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='B' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='1' 
res= hashlib.md5(password.encode())
print(res.hexdigest())
# Out:
# 92eb5ffee6ae2fec3ad71c777531578f
# 9d5ed678fe57bcca610140957afab571
# c4ca4238a0b923820dcc509a6f75849b

# %%
password='t' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='T' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='2' 
res= hashlib.md5(password.encode())
print(res.hexdigest())
# Out:
# e358efa489f58062f10dd7316b65649e
# b9ece18c950afbfa6b0fdbfa4ff731d3
# c81e728d9d4c2f636f067f89cc14862c

# %%
password='s' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='S' 
res= hashlib.md5(password.encode())
print(res.hexdigest())

password='3' 
res= hashlib.md5(password.encode())
print(res.hexdigest())
# Out:
# 03c7c0ace395d80182db07ae2c30f034
# 5dbc98dcc983a70728bd082d1a47546e
# eccbc87e4b5ce2fe28308fd9f2a7baf3

# %%
start = time.process_time()
gen3 = generate('123', 2)
for item3 in gen3:
 print(item3)
finish = time.process_time()
print('Время работы в секундах: ', finish)
# Out:
# 1
# 2
# 3
# Время работы в секундах:  0.21875

# %%
print(string.digits) #123456789
print(string.punctuation)
print(string.ascii_lowercase) # abcdefghijklmnopqrstuvwxyz (строчные буквы)
print(string.ascii_uppercase) # ABCDEFGHIJKLMNOPQRSTUVWXYZ (заглавные буквы)
print(string.ascii_letters) # abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ (все буквы)
print(string.printable) # все печатаемые символы (буквы, цифры, спецсимволы)
# Out:
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
password = 'Enypen'  
res = hashlib.md5(password.encode())  
print(res.hexdigest())
# Out:
# 6d416f7786dbe588eaa6ab48666588d1

# %%
target_hash = res.hexdigest
alphabet = string.printable
start_time = time.time()

for combination in itertools.product(alphabet, repeat=7):
    password = ''.join(combination)  
    test_hash = hashlib.md5(password.encode()).hexdigest() 
    
    if test_hash == target_hash:
        print(f"Пароль найден: {password}")
    break



finish_time = time.time()
print(f"Время подбора: {finish_time - start_time:.6f} сек")
# Out:
# Время подбора: 0.001006 сек
